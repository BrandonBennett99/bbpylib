# %% [markdown]
# # `repo.ibynb` wrapper for `bbpylib/repo.py`
#
# Package configuration (`pyproject.toml`) should be edited via:
#
# [`RepoMan_bbpylib.ipynb`](https://colab.research.google.com/drive/17ZbFRfAgFSMI_6Xb7ZwLnQJRpyfw_ADQ#scrollTo=2adSNG5EX26l)

# %% [markdown]
# ### ToDo
# Incorporate this code to find the latest version on pip:

# %%
import os
from pathlib import Path
#import importlib

GDRIVE_PATH = "/content/drive"
if not  os.path.exists(GDRIVE_PATH):
    from google.colab import drive
    drive.mount(GDRIVE_PATH)

# %%
# !pip uninstall -y bbpylib
# !pip install bbpylib
# Out:
# WARNING: Skipping bbpylib as it is not installed.
# ...

# %%
import os
from pathlib import Path
from bbpylib.colab.tools import require_gdrive
from bbpylib.repo import Repo

require_gdrive() # (verbose=True)
REPO_ROOT = Path("/content/drive/MyDrive/GIT-repos")
repo = Repo("bbpylib", REPO_ROOT, "BrandonBennett99")
repo.update_pip()
# Out:
# Incrementing pip version: 0.1.28 -> 0.1.29
# Building pip package: bbpylib-0.1.29
# Successfully built bbpylib-0.1.29.tar.gz and bbpylib-0.1.29-py3-none-any.whl
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - hatchling>=1.25
# * Getting build dependencies for sdist...
# * Building sdist...
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - hatchling>=1.25
# * Getting build dependencies for wheel...
# * Building wheel...
# bbpylib-0.1.29-py3-none-any.whl
# bbpylib-0.1.29.tar.gz
# Uploading bbpylib-0.1.29 to PyPi ...
# Uploading distributions to https://upload.pypi.org/legacy/
# Uploading bbpylib-0.1.29-py3-none-any.whl
#
#   0% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/12.3 kB • --:-- • ?
#   0% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/12.3 kB • --:-- • ?
#   0% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/12.3 kB • --:-- • ?
# ...

# %%
from  bbpylib.colab.Ed import Ed

# %%
from bbpylib.colab import require_gdrive
require_gdrive()

# %%
## SOME DIAGNOSTICS
# !cat /content/drive/MyDrive/GIT-repos/bbpylib/pyproject.toml
# %pip show -f bbpylib
# Out:
# [build-system]
# requires = ["hatchling>=1.25"]
# build-backend = "hatchling.build"
#
# [project]
# name = "bbpylib"
# version = "0.1.26"
# description = "A personal Python utility library."
# readme = "README.md"
# requires-python = ">=3.9"
# license = { text = "MIT" }
# authors = [
#   { name = "Brandon Bennett" }
# ]
#
# [tool.hatch.build]
# dev-mode-dirs = ["src"]
#
# [tool.hatch.build.targets.wheel]
# #sources = ["src"]
# packages = ["src/bbpylib"]
# Name: bbpylib
# Version: 0.1.25
# Summary: A personal Python utility library.
# Home-page:
# Author: Brandon Bennett
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires:
# Required-by:
# Files:
#   bbpylib-0.1.25.dist-info/INSTALLER
#   bbpylib-0.1.25.dist-info/METADATA
#   bbpylib-0.1.25.dist-info/RECORD
#   bbpylib-0.1.25.dist-info/REQUESTED
#   bbpylib-0.1.25.dist-info/WHEEL
#   bbpylib-0.1.25.dist-info/licenses/LICENSE
#   bbpylib/__init__.py
# ...

# %%
#!cat /content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/colab/tools.py
#!cat /content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/git.py

# %% [markdown]
# ## Upload latest `bbpylib` to `pip` from local repo _**failsafe**_
#
# My intention is that the pubished pip should normally be updated using the `Repo` class in `bbpylib.repo`. But, if, during development, that class breaks due to a bug, it would not be possible to update. So here we have a failsafe version, that should still work if `bbpylib.repo.Repo` is not working correctly and can be used to upload a version that corrects the issue.

# %%
from pathlib import Path
REPO_ROOT = Path("/content/drive/MyDrive/GIT-repos")

import os
import subprocess
import requests
import re

from google.colab import userdata

def run_command(cmd, *, cwd=None, env=None, check=True):
    r = subprocess.run( cmd,
                        cwd=cwd, env=env,
                        text=True, capture_output=True )
    if r.stdout: print(r.stdout, end="")
    if r.stderr: print(r.stderr, end="")
    if check and r.returncode:
        raise subprocess.CalledProcessError(
            r.returncode, r.args, r.stdout, r.stderr)
    return r

import requests

def try_request(url, warn=True, timeout=5):
    try:
        return requests.get(url, timeout=timeout)
    except requests.exceptions.Timeout:
        if warn: print("Error: request timed out")
    except requests.exceptions.ConnectionError:
        if warn: print("Error: network connection failed")
    except requests.exceptions.RequestException as e:
        if warn: print(f"Error: request failed: {e}")
    return None

def published_pip_version(package, warn=True) -> str | None:
    url = f"https://pypi.org/pypi/{package}/json"
    r = try_request(url, warn=warn)
    if r is None:
        return None
    if r.status_code == 404:
        if warn: print(f"Request error 404: Package '{package}' does not exist on PyPI")
        return None
    if r.status_code != 200:
        if warn: print(f"PyPI returned status code {r.status_code}")
        return None
    try:
        data = r.json()
    except ValueError:
        if warn: print("Error: invalid JSON returned from PyPI")
        return None
    return data.get("info", {}).get("version")


def bump_version(v, part="patch"):
    major, minor, patch = map(int, v.split("."))
    if part == "major":
        return f"{major + 1}.0.0"
    if part == "minor":
        return f"{major}.{minor + 1}.0"
    if part == "patch":
        return f"{major}.{minor}.{patch + 1}"
    raise ValueError("part must be 'major', 'minor', or 'patch'")


from pathlib import Path
def set_toml_pip_version(package, new_version, repo_root=REPO_ROOT):
      path = Path(REPO_ROOT/ package/ "pyproject.toml")
      text = path.read_text()
      text, n = re.subn( r'(version\s*=\s*")[^"]+(")',
                        rf'\g<1>{new_version}\g<2>',
                        text, count=1)
      if n != 1:
          raise RuntimeError("Could not uniquely locate version field")
      path.write_text(text)

def build_pip(  package, new_version, repo_root=REPO_ROOT ):
      path = str( Path(repo_root)/ package )
      print(f"Building pip package: {package}-{new_version}")
      run_command( ["rm", "-rf", "dist", "build", "*.egg-info"], cwd=path, check=True )
      run_command( ["pip", "-q", "install", "build"], check=True)
      run_command( ["python", "-m", "build"], cwd=path, check=True)
      run_command( ["ls", "dist"], cwd=path, check=True)

def upload_pip( package, new_version, repo_root=REPO_ROOT ):
      path = str( Path(repo_root)/ package )
      print(f"Uploading {package} new version {new_version} to PyPi ..." )
      pip_api_token= userdata.get("PIP_API_TOKEN")
      env = os.environ.copy()
      env["TWINE_USERNAME"] = "__token__"
      env["TWINE_PASSWORD"] = pip_api_token
      run_command( ["pip", "-q", "install", "twine"], check=True)
      run_command( ["twine", "upload", "--verbose", "dist/*"], cwd=path, env=env, check=True)

def update_pip( package, new_version=None, repo_root=REPO_ROOT ):
    if not new_version:
      published_version = published_pip_version(package)
      print("Published version is", published_version)
      new_version = bump_version(published_version  )
    set_toml_pip_version(package, new_version, repo_root=REPO_ROOT)
    build_pip( package, new_version, repo_root=REPO_ROOT )
    upload_pip( package, new_version, repo_root=REPO_ROOT )

published_pip_version("flubb")
#update_pip("bbpylib")
#upload_pip("bbpylib", "0.1.29" )
# Out:
# Request error 404: Package 'flubb' does not exist on PyPI

# %%
# %%shell
# cd /content/drive/MyDrive/GIT-repos/bbpylib/
# cat pyproject.toml

# %% [markdown]
# ## `bbpylib.repo` code cells

# %%
# %%writefile /content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/process.py
import subprocess

def run_command(cmd, *, cwd=None, env=None, check=True):
    """
    Run an external command, echo stdout/stderr, and raise on failure.

    Parameters
    ----------
    cmd : list[str]           Command and arguments.
    cwd : Path | str | None   Directory to run in.
    check : Bool
    Raises
    ------
    subprocess.CalledProcessError
        If check=True and the command exits with a non-zero status.
    """
    r = subprocess.run(
        cmd,
        cwd=cwd,
        env=env,
        text=True,
        capture_output=True
    )
    if r.stdout: print(r.stdout, end="")
    if r.stderr: print(r.stderr, end="")
    if check and r.returncode:
        raise subprocess.CalledProcessError(
            r.returncode, r.args, r.stdout, r.stderr)
    return r
# Out:
# Overwriting /content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/process.py

# %%
# %%writefile /content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/repo.py
## Written from repo.ipynb

import tomllib
from pathlib import Path
import subprocess
import os, sys, site
import requests
import re

# Import from process.py in this package
try:
  from .process import run_command
except:
  print("Could not import .process (maybe loaded from a cell)")

try:
  from google.colab import userdata
  GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
  PIP_API_TOKEN = userdata.get("PIP_API_TOKEN")
except:
  print("Could not get tokens via google.colab.userdata")
  GITHUB_TOKEN = None
  PIP_API_TOKEN = None


class Repo:
  def __init__(self, name, location, user,
               git_token=GITHUB_TOKEN, pip_token = PIP_API_TOKEN):
    self.name = name
    self.location = location
    self.user = user
    self.git_token = git_token
    self.pip_token = pip_token
    self.root =  Path( Path(location)/ name )
    self.src =  Path( self.root, "src", name )
    self.git = GitCommander(self)
    self.version = "batfish"

  def pyproject_toml_pip_version(self):
      with open(self.root/"pyproject.toml", "rb") as f:
          data = tomllib.load(f)
      return data["project"]["version"]

  def published_pip_version(self) -> str | None:
      url = f"https://pypi.org/pypi/{self.name}/json"
      r = requests.get(url, timeout=5)
      if r.status_code != 200:
          return None  # package not found or network error
      data = r.json()
      # 'info' is the metadata for the *latest* release
      return data.get("info", {}).get("version")


  def set_version(self, new_version):
      path = Path(self.root/"pyproject.toml")
      text = path.read_text()
      text, n = re.subn( r'(version\s*=\s*")[^"]+(")',
                        rf'\g<1>{new_version}\g<2>',
                        text, count=1)
      if n != 1:
          raise RuntimeError("Could not uniquely locate version field")
      path.write_text(text)

  def increment_pip_version(self, level="patch"):
      v = self.published_pip_version()
      nv = bump_version(v, level=level)
      print("Incrementing pip version:", v, "->", nv)
      self.set_version(nv)

  def show_config(self):
      with open(self.root/"pyproject.toml", "r") as f:
          print( f.read() )

  def check_repo_files( self ):
      root = self.root
      print("pyproject:", (root/"pyproject.toml").exists())
      print("src dir:", (root/"src").is_dir())
      print("pkg dir:", (root/"src"/self.name).is_dir())
      print("__init__.py:", (root/"src"/self.name/"__init__.py").exists())

  def build_pip(self):
      print(f"Building pip package: {self.name}-{self.pyproject_toml_pip_version()}")
      run_command( ["rm", "-rf", "dist", "build", "*.egg-info"], cwd=self.root, check=True )
      run_command( ["pip", "-q", "install", "build"], check=True)
      run_command( ["python", "-m", "build"], cwd=self.root, check=True)
      run_command( ["ls", "dist"], cwd=self.root, check=True)

  def upload_pip(self):
      print(f"Uploading {self.name}-{self.pyproject_toml_pip_version()} to PyPi ..." )
      env = os.environ.copy()
      env["TWINE_USERNAME"] = "__token__"
      env["TWINE_PASSWORD"] = self.pip_token
      run_command( ["pip", "-q", "install", "twine"], check=True)
      run_command( ["twine", "upload", "dist/*"], cwd=self.root, env=env, check=True)

  def update_pip(self,level="patch", version=None):
      if version:
        print("Setting repo pip version to", version)
        self.set_version(version)
      else:
        self.increment_pip_version(level=level)
      self.build_pip()
      self.upload_pip()

  def install_editable(self):
     install_editable(self.name, self.location)


# This is just a str->str function so not in the class
def bump_version(v, level="patch"):
    major, minor, patch = map(int, v.split("."))
    if level == "major":
        return f"{major + 1}.0.0"
    if level == "minor":
        return f"{major}.{minor + 1}.0"
    if level == "patch":
        return f"{major}.{minor}.{patch + 1}"
    raise ValueError("'level' parameter must be 'major', 'minor', or 'patch'")


class GitCommander:
    def __init__(self, repo):
        self.repo = repo
        self.name = repo.name
        self.user = repo.user
        self.token = repo.git_token
        self.url = f"https://{self.user}:{self.token}@github.com/{self.user}/{self.name}.git"

    def git_command(self, *cmd, check=True):
        return run_command(["git", *cmd], cwd=self.repo.root, check=check)

    def status(self):        return self.git_command("status")
    def status_short(self):  return self.git_command("status", "-sb")

    def add(self, *files):
        if files:
           return self.git_command("add", files )
        return self.git_command("add", "-A")

    def commit(self, message="Committing minor updates."):
        if self.git_command( "diff", "--cached", "--quiet", check=False ).returncode == 0:
            print("No changes to commit.")
            return
        return self.git_command("commit", "-m", message)

    def push(self):
        self.git_command( "push", self.url )

    def update(self, message="Committing minor updates."):
        self.add()
        self.commit(message=message)
        self.push()

    def fetch(self):
        return self.git_command( "fetch", self.url )

    def merge(self):
        self.git_command( "merge", "FETCH_HEAD" )

    def pull(self):
        self.fetch()
        self.merge()

    # Don't really need to do this as can pass the token directly
    def set_token_remote(self, remote="origin"):
        return self._git("remote", "set-url", remote, self.url)

    def is_up_to_date(self):
        self.fetch()
        r = self.git_command( "rev-list", "--left-right", "--count", "HEAD...@{u}" )
        ahead, behind = map(int, r.stdout.split())
        return (ahead == 0 and behind == 0)


def pyproject_toml_str(
    package_name: str,
    version: str,
    description: str = "",
    requires_python: str = ">=3.9",
    author_name: str | None = None,
    readme: str | None = "README.md",
    license_text: str | None = "MIT",
) -> str:
    """
    Return a minimal pyproject.toml string suitable for a Hatchling build
    using a standard `src/<package_name>` layout.
    """

    lines = ["# pyproject.toml auto created by BB's pyproject_toml_str function"]

    # --- build system ---
    lines.append("[build-system]")
    lines.append('requires = ["hatchling>=1.25"]')
    lines.append('build-backend = "hatchling.build"')
    lines.append("")

    # --- project metadata ---
    lines.append("[project]")
    lines.append(f'name = "{package_name}"')
    lines.append(f'version = "{version}"')

    if description:
        lines.append(f'description = "{description}"')

    if readme:
        lines.append(f'readme = "{readme}"')

    lines.append(f'requires-python = "{requires_python}"')

    if license_text:
        lines.append(f'license = {{ text = "{license_text}" }}')

    if author_name:
        lines.append("authors = [")
        lines.append(f'  {{ name = "{author_name}" }}')
        lines.append("]")

    lines.append("")

    # --- hatch build config ---
    lines.append("[tool.hatch.build]")
    lines.append('dev-mode-dirs = ["src"]')
    lines.append("")

    lines.append("[tool.hatch.build.targets.wheel]")
    lines.append(f'packages = ["src/{package_name}"]')

    return "\n".join(lines)

def install_editable(repo_name, location, src_subdir="src"):
    """
    Uninstall package_name (if present) and install the repo at repo_path
    in editable mode.
    """
    repo_path = Path(location)/repo_name
    src_path = repo_path / src_subdir
    run_command(["pip", "uninstall", "-y", repo_name])
    run_command(["pip", "install", "-e", str(repo_path)])
    ## It seems you need this to make the -e installed package accessible in Colab
    if src_path.exists():
        site.addsitedir(str(src_path))

def test():
    print("bbpylib.repo.test says: Hello")
# Out:
# Overwriting /content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/repo.py

# %%
import site
from bbpylib.process import run_command
def install_editable(repo_name, repo_root, src_subdir="src"):
    """
    Uninstall package_name (if present) and install the repo at repo_path
    in editable mode.
    """
    repo_path = Path(repo_root)/repo_name
    src_path = repo_path / src_subdir
    run_command(["pip", "uninstall", "-y", repo_name])
    run_command(["pip", "install", "-e", str(repo_path)])
    ## It seems you need this to make the -e installed package accessible in Colab
    if src_path.exists():
        site.addsitedir(str(src_path))

from pathlib import Path
GIT_repos_PATH = Path("/content/drive/MyDrive/GIT-repos")
install_editable("bbpylib", GIT_repos_PATH)
# Out:
# Found existing installation: bbpylib 0.1.20
# Uninstalling bbpylib-0.1.20:
#   Successfully uninstalled bbpylib-0.1.20
# Obtaining file:///content/drive/MyDrive/GIT-repos/bbpylib
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for bbpylib (pyproject.toml): started
#   Building editable for bbpylib (pyproject.toml): finished with status 'done'
# ...

# %% [markdown]
# ## Tests

# %%
# !pip install bbpylib

# %%
import bbpylib.repo
bbpylib.repo.install_editable("bbpylib", REPO_ROOT)
# Out:
# Found existing installation: bbpylib 0.1.24
# Uninstalling bbpylib-0.1.24:
#   Successfully uninstalled bbpylib-0.1.24
# Obtaining file:///content/drive/MyDrive/GIT-repos/bbpylib
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# ...
#   Building editable for bbpylib (pyproject.toml): started
#   Building editable for bbpylib (pyproject.toml): finished with status 'done'
# ...

# %%
dir(bbpylib)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'foobar',
#  'process',
#  'repo']

# %%
from pathlib import Path
import bbpylib
bbpylib.colab.tools.require_gdrive() # (verbose=True)
from  bbpylib.colab.Ed import Ed

REPO_ROOT = Path("/content/drive/MyDrive/GIT-repos")
from bbpylib.repo import Repo
bbpylib_repo = Repo("bbpylib", REPO_ROOT, "BrandonBennett99")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_176/2102494316.py in <cell line: 0>()
#       1 from pathlib import Path
#       2 import bbpylib
# ----> 3 bbpylib.colab.tools.require_gdrive() # (verbose=True)
#       4 from  bbpylib.colab.Ed import Ed
#       5
#
# AttributeError: module 'bbpylib' has no attribute 'colab'

# %%
import importlib
import bbpylib.repo
#importlib.reload(bbpylib.repo)
#importlib.reload(bbpylib.process)
bbpylib.repo.test()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_73090/11767611.py in <cell line: 0>()
#       3 #importlib.reload(bbpylib.repo)
#       4 #importlib.reload(bbpylib.process)
# ----> 5 bbpylib.repo.test()
#
# AttributeError: module 'bbpylib.repo' has no attribute 'test'

# %%
## It seems you need this to make the -e installed package accessible
import site
site.addsitedir("/content/drive/MyDrive/GIT-repos/bbpylib/src")

import importlib

# %%
importlib.reload(bbpylib.repo)
importlib.reload(bbpylib.process)
pyproject_content = bbpylib.repo.pyproject_toml_str("reponame", "0.0.0", readme=None)
print(pyproject_content)
# Out:
# # pyproject.toml auto created by BB's pyproject_toml_str function
# [build-system]
# requires = ["hatchling>=1.25"]
# build-backend = "hatchling.build"
#
# [project]
# name = "reponame"
# version = "0.0.0"
# requires-python = ">=3.9"
# license = { text = "MIT" }
#
# [tool.hatch.build]
# dev-mode-dirs = ["src"]
#
# [tool.hatch.build.targets.wheel]
# packages = ["src/reponame"]

# %%
import bbpylib
import bbpylib.colab.Ed
import bbpylib.repo
import bbpylib.process
from pathlib import Path

Repo_ROOT_str = "/content/drive/MyDrive/GIT-repos"
Repo_ROOT = Path(Repo_ROOT_str)

# %%
import importlib
importlib.reload(bbpylib.repo)
importlib.reload(bbpylib.process)
lib_repo = bbpylib.repo.Repo("bbpylib", Repo_ROOT, "BrandonBennett99")

lib_repo.root
lib_repo.pip_version()
print("Version tag:", lib_repo.version )
lib_repo.git.update( f"Running git.update from {lib_repo.version} version.")

lib_repo.update_pip()
# Out:
# Version tag: batfish
# [master 5c6bf63] Running git.update from batfish version.
#  4 files changed, 4 insertions(+), 4 deletions(-)
#  rewrite RepoMan_bbpylib.ipynb (76%)
#  rewrite code_nb_wrappers/repo.ipynb (98%)
# To https://github.com/BrandonBennett99/bbpylib.git
#    506005e..5c6bf63  master -> master
# Incrementing pip version: 0.1.16 -> 0.1.17
# Building pip package: bbpylib-0.1.17
# Successfully built bbpylib-0.1.17.tar.gz and bbpylib-0.1.17-py3-none-any.whl
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - hatchling>=1.25
# * Getting build dependencies for sdist...
# * Building sdist...
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - hatchling>=1.25
# * Getting build dependencies for wheel...
# * Building wheel...
# bbpylib-0.1.17-py3-none-any.whl
# bbpylib-0.1.17.tar.gz
# Uploading bbpylib-0.1.17 to PyPi ...
# ...

# %% [markdown]
# ## Other diagnostic stuff

# %%
import importlib
import importlib.util
import sys
from pathlib import Path

def import_from_path(module_name, path):
    path = Path(path)
    spec = importlib.util.spec_from_file_location(module_name, path)
    module = importlib.util.module_from_spec(spec)
    sys.modules[module_name] = module
    spec.loader.exec_module(module)
    return module

#import_from_path("repo", "/content/drive/MyDrive/GIT-repos/bbpylib/src/bbpylib/repo.py")
